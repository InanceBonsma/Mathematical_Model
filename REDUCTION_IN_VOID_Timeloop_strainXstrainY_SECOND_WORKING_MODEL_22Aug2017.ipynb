# %% [markdown]
# # 3D Geometric Model of Inflated Dunnage Bag - Reduction in Void

# %% [markdown]
# ## Assumptions:

# %% [markdown]
# 1. Material is rigid
# 2. Idealized geometry
# 3. Not rate dependent
# 4. Mass is constant
# 5. Temperature has no effect on the material or the inflated air

# %% [markdown]
# ## Import Libraries:

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt, numpy as np
from scipy.interpolate import spline
from math import pi #import pi function for simple reference

# %% [markdown]
# ## Functions:

# %%
#Find volume from length, width and diameter
def updateVolume(width,length,diameter):
    LengthLong = width - float(pi*diameter)/2 
    AreaLong = diameter*LengthLong + float(pi*diameter**2)/4
    LengthShort = length - float(pi*diameter)/2
    AreaShort = diameter*LengthShort + float(pi*diameter**2)/4
    VolumeSphere = float(1/6)*(diameter**3)*(pi)
    return (AreaLong*LengthShort) + (AreaShort*LengthLong) + VolumeSphere

# %%
#Update the Pressure using Ideal Gas Law
def updatePressure(mass,volume):
    return mass*8.3144598*298.15/volume

# %%
#Get the mass using the Ideal Gas Law (ABSOLUTE PRESSURE)
def updateMass(pressure,volume):
    return((101500-pressure) *volume)/(8.3144598*298.15)

# %%
#Get stess from Barlow's formula
def updateStress(diameter,pressure): 
    return (diameter*(pressure))/(2*1)

# %%
#Find the new length using the strain calculated - WARP
def updateLength(length,strain):
    ChangeInLength = length*strain 
    return length+ChangeInLength

# %%
#Find the new width using the strain calculated - WEFT
def updateWidth(width,strain):
    ChangeInWidth = width*strain 
    return width+ChangeInWidth

# %%
#Get strain from stress-strain curve
def getStrain(stress,strain,stress_barlow):
    index = np.array(stress).searchsorted(stress_barlow)#find index from barlow's stress value
    x2 = strain[index-1] #find strain value to left
    x1 = strain[index] #find strain value to right
    y2 = stress[index-1] #find stress value to left
    y1 = stress[index] #find stress value to right
    return x1 + (stress_barlow-y1)*(x2 - x1)/(y2 - y1)

# %%
#Get new void size (new diameter), using Barlow Formula (RELATIV PRESSURE)
def updateDiameter(stress,pressure): 
    return 2*stress*1/(pressure)

# %% [markdown]
# ## Import Data for Stress-Strain:

# %%
def StressStrainData(textfile):
    with open(textfile,'r') as file:
        lst = [] 
        for line in file:
            lst.append([ float(x) for x in line.split()])
        force = np.array([ x[0] for x in lst])
        stress =(np.array([ x[1] for x in lst]))
        stress = (stress)*100
        strain =np.array([ x[2] for x in lst])
        time =np.array([ x[3] for x in lst])
    return force, stress, strain, time

# %%
textfile_WEFT =  'C:\\Users\\Inance\\Documents\\Thesis\\Mathematical_Model\\MATHEMATICAL_MODEL_OUTPUT_FILES\\average_tensile_7threads_weft.txt'
textfile_WARP =  'C:\\Users\\Inance\\Documents\\Thesis\\Mathematical_Model\\MATHEMATICAL_MODEL_OUTPUT_FILES\\average_tensile_7threads_warp.txt'
force_WA, sig_WA, eps_WA, time_WA = StressStrainData(textfile_WARP)
force_WE, sig_WE, eps_WE, time_WE = StressStrainData(textfile_WEFT)

# %% [markdown]
# ## Input Parameters - Main A:

# %%
#Constants:
w_WE=[1.2] #0.9
d=0.5
l_WA=[1.8]#[1.5] #initial length

#Initial values:

P=[20] #kPa #[20000]  #initial GAUGE pressure (20 kPa)
V=[1]
m=[updateMass(P[0],V[0])] #initial mass from Ideal Gas Law
sig_b = [updateStress(d,P[0])] #initial stress form Barlows
epsa_WA = [0.0] #initial strain in warp direction
epsa_WE = [0.0] #initial strain in weft direction

#print ('sig =',sig,'\n','eps =',eps,)
print ('\n','P =',P,'\n','V =',V,'\n','m =',m,'\n','sig_b =',sig_b)

# Main A - loop parameters:
max_iter = 20 #maximum number of iterations
m_tol = 0.0005 #mass tolerance
i = 0 #starting number of iteration
m_diff = 10.0 #
m_old = 100 #old mass
# Out:
#  P = [20]
#  V = [1]
#  m = [40.93658469445967]
#  sig_b = [5.0]

# %% [markdown]
# ## Main A - Just Inflated:

# %%
print("{0}   {1}    {2}    {3}       {4}       {5}          {6}             {7}".format("P","epsa_WA","epsa_WE","l_WA","w_WE","V","m","sig_b"))
while (m_diff >= m_tol and i < max_iter):
    P.append(P[0]) #update Pressure
    
    sig_b.append(updateStress(d,P[i+1])) #get Stress using Barlow's formula, GAUGE PRESSURE
    
    epsa_WA.append(getStrain(sig_WA,eps_WA,sig_b[i+1])) #get Strain in WARP direction
    
    epsa_WE.append(getStrain(sig_WE,eps_WE,sig_b[i+1])) #get Strain in WEFT direction
    
    l_WA.append(updateLength(l_WA[0],epsa_WA[i+1]))#get updated length
    
    w_WE.append(updateWidth(w_WE[0],epsa_WE[i+1]))#get updated width
    
    V.append(updateVolume(w_WE[i+1],l_WA[i+1],d)) #get Volume
    
    m.append(updateMass(P[i+1],V[i+1])) #initial mass from Ideal Gas Law, ABSOLUTE PRESSURE
    
    #Loop constraints
    m_diff = np.abs(m[i+1] - m_old) #calculate abs difference between old m and new m
    m_old = m[i+1] #set the old m equal to the current m for the next loop
    
    print("{0}  {1:.6f}   {2:.6f}   {3:.6f}   {4:.6f}   {5:.6f}   {6:.6f}     {7}".format(P[i+1],epsa_WA[i+1],epsa_WE[i+1],l_WA[i+1],w_WE[i+1],V[i+1],m[i+1],sig_b[i+1]))

    i+=1 #increment i to loop ,V,m,sig_b
# Out:
# P   epsa_WA    epsa_WE    l_WA       w_WE       V          m             sig_b
# 20  0.000040   0.000059   1.800072   1.200071   0.766859   31.392587     5.0
# 20  0.000040   0.000059   1.800072   1.200071   0.766859   31.392587     5.0

# %% [markdown]
# ## Import Single Cycle Full Scale Bag Data:

# %%
def CyclicBagData():
    textfile = 'C:\\Users\\Inance\\Documents\\Thesis\\Mathematical_Model\\MATHEMATICAL_MODEL_OUTPUT_FILES\\average_single_cycle.txt'
    with open(textfile,'r') as file:
        lst = [] 
        for line in file:
            lst.append([ float(x) for x in line.split()])
        time = np.array([ x[0] for x in lst])
        void =(np.array([ x[1] for x in lst]))
        void = (void)*0.001
        pressure =np.array([ x[2] for x in lst])
        #pressure = (pressure) *1000
    return time,void,pressure

# %%
def getNumber(specific_list,position):
    specific_list=specific_list.tolist()
    if position%2==0: #even numbers
        IndexPosition = specific_list.index(min(specific_list)) #void size is lowest
    else: #uneven number
        IndexPosition = specific_list.index(max(specific_list)) #void size is highest
    return specific_list[IndexPosition]

# %%
def getIndex(specific_list,position):
    specific_list=specific_list.tolist()
    if position%2==0:
        IndexPosition = specific_list.index(min(specific_list))
    else:
        IndexPosition = specific_list.index(max(specific_list))
    return IndexPosition

# %%
#Import Single Cycle Burst Data:
Cyclic_Time,Cyclic_Void,Cyclic_Pressure = CyclicBagData()

#Look at specific max-to-min void reduction list:
void_start = Cyclic_Void[(getIndex(Cyclic_Void,1)):] #cut off starting values before max
void_final = void_start[:(getIndex(Cyclic_Void,2))] #cut off final value after min, final single cycle void list
#print(void_final)

#Look at specific max-to-min void reduction list:
pressure_start = Cyclic_Pressure[(getIndex(Cyclic_Void,1)):] #cut off starting values before max
pressure_final = pressure_start[:(getIndex(Cyclic_Void,2))] #cut off final value after min, final single cycle void list
#print(pressure_final)

print(len(void_final),len(pressure_final))
# Out:
# 380 380

# %% [markdown]
# ## Input Parameters - Main B:

# %%
#Loop parameters:
max_iter = 400
k = 0 #number of iterations
l_tol = 0.0005
l_diff = 10.0
l_old = 100
list_size=1

#Input parameters for Main B:
d_red=np.empty((list_size, 0)).tolist()
d_red[0] = void_final[0]

P_red=np.empty((list_size, 0)).tolist()
P_red[0] = pressure_final[0] #diameter which is reduced
P_ideal=np.empty((list_size, 0)).tolist()
P_ideal[0] = P[2] #end pressure of Main A, starting pressure for Main B


m_red = [m[2]] #end mass of Main A, starting mass for Main B
V_red = [V[2]] #end volume of Main A, starting volume for Main B

sig_b_red = [sig_b[2]] #end barlow stress of Main A, starting barlow stress for Main B
epsa_red_WA = [epsa_WA[2]] #end strain of Main A, starting strain for Main B
epsa_red_WE = [epsa_WE[2]] #end strain of Main A, starting strain for Main B
l_red = [l_WA[2]] #end length of Main A, starting length for Main B
w_red = [w_WE[2]] #end width of Main A, starting width for Main B

print("{0:.4f}  {1:.4f}  {2:.4f}  {3:.4f}  {4:.4f}  {5}".format(P_red[0],d_red[0],epsa_red_WA[0],epsa_red_WE[0],V_red[0],sig_b_red[0]))
# Out:
# 11.9575  0.3056  0.0000  0.0001  0.7669  5.0

# %% [markdown]
# ## MAIN - Time loop:

# %%
t_max_index = getIndex(Cyclic_Void,1) #time start
t_min_index = getIndex(Cyclic_Void,2) #time end
t_length = (Cyclic_Time.tolist()[t_min_index] - Cyclic_Time.tolist()[t_max_index]) #nr of data points in interested timeline
print(t_length,t_length/0.02)
t=0
# Out:
# 7.040000000000001 352.00000000000006

# %% [markdown]
# ## Main B - Reduction in Void:

# %%
print("{0}      {1}      {2}       {3}      {4}   {5}      {6}      {7}    {8}".format("t","d_red","P_red","m_red","epsa_red_WA","V_red","l_red","w_red","sig_b_red"))

while t <= t_length and k < max_iter:
    
    P_ideal.append(updatePressure(m_red[0],V_red[k])) #get PRESSURE from ideal gas law
    
    P_red.append(pressure_final[k+1]) #get PRESSURE from experimental data

    sig_b_red.append(updateStress(d_red[k],P_red[k])) #get STRESS from barlow's formula
    
    epsa_red_WA.append(getStrain(sig_WA,eps_WA,sig_b_red[k+1]))#get STRAIN from experimental stress-strain curve
    
    epsa_red_WE.append(getStrain(sig_WE,eps_WE,sig_b_red[k+1]))#get STRAIN from experimental stress-strain curve
        
    l_red.append(updateLength(l_red[k],epsa_red_WA[k+1]))#get NEW LENGTH from strain formula
    
    w_red.append(updateWidth(w_red[k],epsa_red_WE[k+1]))#get NEW WIDTH from strain formula
    
    d_red.append(void_final[k+1])#get actual DIAMETER from experimental data
    
    #m_red.append(updateMass(P_red[k+1],V_red[k])) #get MASS from ideal gas law
    
    V_red.append(updateVolume(w_red[k+1],l_red[k+1],d_red[k+1])) #get VOLUME from idealized geometry
    
    #Loop constraints
    l_diff = np.abs(l_red[k+1] - l_old) #calculate abs difference between old V and new V
    l_old = l_red[k+1] #set the old V equal to the current V for the next loop
    
    print("{0:.2f}   {1:.6f}   {2:.6f}   {3:.6f}   {4:.6f}   {5:.6f}   {6:.6f}   {7:.6f}   {8:.6f}".format(t,d_red[k],P_red[k+1],m_red[0],epsa_red_WA[k+1],V_red[k+1],l_red[k+1],w_red[k+1],sig_b_red[k+1]))
    k+=1 #increment k to loop 
    t+=0.02
# Out:
# t      d_red      P_red       m_red      epsa_red_WA   V_red      l_red      w_red    sig_b_red
# 0.00   0.305553   11.965000   31.392587   0.000023   0.745529   1.800113   1.200112   1.826826
# 0.02   0.305553   11.987500   31.392587   0.000023   0.745585   1.800154   1.200153   1.827972
# 0.04   0.305551   12.012500   31.392587   0.000023   0.745639   1.800194   1.200195   1.831399
# 0.06   0.305548   12.010000   31.392587   0.000023   0.745692   1.800235   1.200236   1.835196
# 0.08   0.305542   12.017500   31.392587   0.000023   0.745728   1.800276   1.200278   1.834781
# 0.10   0.305517   12.052500   31.392587   0.000023   0.745742   1.800317   1.200319   1.835773
# 0.12   0.305465   12.082500   31.392587   0.000023   0.745743   1.800357   1.200360   1.840811
# 0.14   0.305398   12.095000   31.392587   0.000023   0.745722   1.800398   1.200402   1.844985
# 0.16   0.305305   12.122500   31.392587   0.000023   0.745691   1.800439   1.200443   1.846330
# 0.18   0.305200   12.145000   31.392587   0.000023   0.745658   1.800480   1.200485   1.849896
# 0.20   0.305093   12.187500   31.392587   0.000023   0.745622   1.800521   1.200526   1.852675
# 0.22   0.304981   12.225000   31.392587   0.000023   0.745597   1.800562   1.200568   1.858479
# 0.24   0.304884   12.250000   31.392587   0.000023   0.745584   1.800603   1.200610   1.863606
# 0.26   0.304800   12.277500   31.392587   0.000023   0.745578   1.800644   1.200651   1.866902
# 0.28   0.304725   12.305000   31.392587   0.000023   0.745574   1.800685   1.200693   1.870632
# 0.30   0.304652   12.315000   31.392587   0.000023   0.745568   1.800726   1.200735   1.874371
# 6.78   0.193831   60.117500   31.392587   0.000045   0.613108   1.820244   1.220078   5.809364
# 6.80   0.193596   60.297500   31.392587   0.000045   0.612725   1.820326   1.220158   5.819266
# 6.82   0.193365   60.470000   31.392587   0.000045   0.612363   1.820407   1.220238   5.829723
# 6.84   0.193145   60.587500   31.392587   0.000045   0.612041   1.820489   1.220318   5.839746
# 6.86   0.192945   60.692500   31.392587   0.000045   0.611778   1.820571   1.220398   5.845035
# 6.88   0.192774   60.792500   31.392587   0.000045   0.611562   1.820652   1.220478   5.849981
# 6.90   0.192627   60.890000   31.392587   0.000045   0.611415   1.820734   1.220558   5.855150
# 6.92   0.192515   60.962500   31.392587   0.000045   0.611321   1.820816   1.220638   5.861121
# 6.94   0.192428   61.002500   31.392587   0.000045   0.611281   1.820898   1.220718   5.865456
# 6.96   0.192369   61.020000   31.392587   0.000045   0.611275   1.820980   1.220798   5.867494
# 6.98   0.192326   61.020000   31.392587   0.000045   0.611309   1.821062   1.220878   5.867868
# 7.00   0.192303   61.017500   31.392587   0.000045   0.611366   1.821144   1.220958   5.867172
# 7.02   0.192291   61.020000   31.392587   0.000045   0.611434   1.821226   1.221038   5.866572
# 7.04   0.192285   61.017500   31.392587   0.000045   0.611535   1.821307   1.221118   5.866620

# %% [markdown]
# ## Iteration Graphs:

# %%
#Create Figures
axis_font = {'size':'12'} #customize graph
def CreateGraphs(x_list,y_list,name_x,name_y,i):
    fig = plt.figure(figsize=(7,25)) 
    ax = fig.add_subplot(7,1,i)
    ax.plot(x_list, y_list) #create a scatter plot
    plt.ylabel(name_x,**axis_font),plt.xlabel(name_y,**axis_font) #name axes
    plt.show() #show graph
    #fig.savefig(path.join(outpath,"{0}_vs_{1}.png".format(name_x,name_y)))
    return

# %%
CreateGraphs(range(len(P_red)),P_red,"Pressure [kPa] (Cyclic Data)","Iteration number",1)
#CreateGraphs(range(len(P_ideal)),P_ideal,"Pressure (Ideal Gas Law)","Iteration number",2)
CreateGraphs(range(len(d_red)),d_red,"Diameter [m]","Iteration number",2)
CreateGraphs(range(len(epsa_red_WA)),epsa_red_WA,"Strain (Warp)","Iteration number",3)
CreateGraphs(range(len(epsa_red_WE)),epsa_red_WE,"Strain (Weft)","Iteration number",4)
CreateGraphs(range(len(V_red)),V_red,"Volume","Iteration number",5)
CreateGraphs(range(len(sig_b_red)),sig_b_red,"Barlow's Stress","Iteration number",6)
CreateGraphs(sig_b_red,P_red,"Barlow's Stress","Pressure",7)

# %%
#Import Single Cycle Burst Data:
Cyclic_Time,Cyclic_Void,Cyclic_Pressure = CyclicBagData()

#cut off starting values before max
void_start,pressure_start = zip(*[[Cyclic_Void[i], Cyclic_Pressure[i]] for i in range(len(Cyclic_Void)) if Cyclic_Void[i]<Cyclic_Void[getIndex(Cyclic_Void,1)]]) 
#cut off final value after min, final single cycle void list
void_final,pressure_final = zip(*[[void_start[i], pressure_start[i]] for i in range(len(void_start)) if void_start[i]>void_start[getIndex(Cyclic_Void,2)]])
